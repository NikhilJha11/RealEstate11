# %% [markdown]
# <a href="https://colab.research.google.com/github/NikhilJha11/RealEstate11/blob/Python(EDA%26ENG)/RealEstateEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('RealEstate_Preprocessed1.csv', encoding='unicode_escape')

df.head(5)
# Out:
#                                 ï»¿Name  \
# 0                      Casagrand ECR 14
# 1   Ramanathan Nagar PozhichalurChennai
# 2                           DAC Prapthi
# 3  NaveenilayaChepauk TriplicaneChennai
# 4              VGN Spring Field Phase 1
#
#                                       Property_Title  Price_InLakhs  \
# 0  4 BHK Flat for sale in Kanathur Reddikuppam Ch...            199
# 1  10 BHK Independent House for sale in Pozhichal...            225
# 2       3 BHK Flat for sale in West Tambaram Chennai            100
# 3  7 BHK Independent House for sale in Triplicane...            333
# 4               2 BHK Flat for sale in Avadi Chennai             48
#
#                                  Location  Total_Area  Price_per_SQFT  Baths  \
# 0            Kanathur Reddikuppam Chennai        2583            7700      4
# 1     Ramanathan Nagar PozhichalurChennai        7000            3210      6
# ...

# %%
df = df.rename(columns={'ï»¿Name': 'Name'})

# %%
(df["Typeof_flat"].value_counts()).plot.pie(autopct="%.1f%%", shadow=True,rotatelabels=True, wedgeprops={'linewidth': 6}, radius=2.5)
plt.show()

# %%
df.shape
# Out:
# (14528, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14528 entries, 0 to 14527
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿Name         14528 non-null  object
#  1   Property_Title  14528 non-null  object
#  2   Price_InLakhs   14528 non-null  int64
#  3   Location        14528 non-null  object
#  4   Total_Area      14528 non-null  int64
#  5   Price_per_SQFT  14528 non-null  int64
#  6   Baths           14528 non-null  int64
#  7   Balcony         14528 non-null  int64
#  8   Typeof_flat     14507 non-null  object
#  9   City            14528 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# Out:
#        ï»¿Name  Property_Title  Price_InLakhs  Location  Total_Area  \
# 0        False           False          False     False       False
# 1        False           False          False     False       False
# 2        False           False          False     False       False
# 3        False           False          False     False       False
# 4        False           False          False     False       False
# ...        ...             ...            ...       ...         ...
# 14523    False           False          False     False       False
# 14524    False           False          False     False       False
# 14525    False           False          False     False       False
# 14526    False           False          False     False       False
# 14527    False           False          False     False       False
#
#        Price_per_SQFT  Baths  Balcony  Typeof_flat   City
# 0               False  False    False        False  False
# ...

# %%
df[['Name','City','Typeof_flat']].describe()
# Out:
#                      Name       City Typeof_flat
# count               14528      14528       14507
# unique               9987          8          25
# top     Classic Apartment  Bangalore       2 BHK
# freq                   42       4513        5678

# %%
df.columns
# Out:
# Index(['Name', 'Property_Title', 'Price_InLakhs', 'Location', 'Total_Area',
#        'Price_per_SQFT', 'Baths', 'Balcony', 'Typeof_flat', 'City'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                   count          mean           std   min     25%     50%  \
# Price_InLakhs   14528.0    106.716134    186.738079   1.0    37.0    65.0
# Total_Area      14528.0   1297.916988   1245.694305  70.0   650.0  1000.0
# Price_per_SQFT  14528.0  11719.456222  49036.068632   0.0  4480.0  6050.0
# Baths           14528.0      2.751239      0.898243   1.0     2.0     3.0
# Balcony         14528.0      0.590584      0.491743   0.0     0.0     1.0
#
#                    75%       max
# Price_InLakhs    114.0    8400.0
# Total_Area      1439.0   35000.0
# Price_per_SQFT  9312.5  999000.0
# Baths              3.0       6.0
# Balcony            1.0       1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
#Checking if there is some null values or not (Sum)
df.isnull().sum()
df['City'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Hyderabad', 'Mumbai', 'Thane', 'Kolkata',
#        'Pune', 'Delhi'], dtype=object)

# %%
df['Typeof_flat'].unique()
# Out:
# array(['4 BHK', '10 BHK', '3 BHK', '7 BHK', '2 BHK', '1 BHK', '6 BHK',
#        '5 BHK', '1 RK', '8 BHK', '1.5 BHK', '2.5 BHK', '9 BHK', '3.5 BHK',
#        '5+ BHK', nan, '6 RK', '10.5 BHK', '4.5 BHK', '9.5 BHK', '8.5 BHK',
#        '7.5 BHK', '5 RK', '2 RK', '3 RK', '4 RK'], dtype=object)

# %%
df['Price_InLakhs'].sum()
# Out:
# 1550372

# %%
df.City.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
df[['Balcony','Baths']].value_counts().plot(kind='bar') # Changed 'Banlcony' to 'Balcony'
# Out:
# <Axes: xlabel='Balcony,Baths'>

# %%
import warnings
warnings.filterwarnings('ignore')

sns.FacetGrid(df, hue='Typeof_flat', height=6).map(sns.distplot, 'Baths').add_legend() # Changed 'bath' to 'Baths'
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

sns.FacetGrid(df, hue='Balcony', height=6).map(sns.distplot, 'Total_Area').add_legend() # Changed 'bath' to 'Baths'
plt.show()

# %%
df.head(5)
# Out:
#                                 ï»¿Name  \
# 0                      Casagrand ECR 14
# 1   Ramanathan Nagar PozhichalurChennai
# 2                           DAC Prapthi
# 3  NaveenilayaChepauk TriplicaneChennai
# 4              VGN Spring Field Phase 1
#
#                                       Property_Title  Price_InLakhs  \
# 0  4 BHK Flat for sale in Kanathur Reddikuppam Ch...            199
# 1  10 BHK Independent House for sale in Pozhichal...            225
# 2       3 BHK Flat for sale in West Tambaram Chennai            100
# 3  7 BHK Independent House for sale in Triplicane...            333
# 4               2 BHK Flat for sale in Avadi Chennai             48
#
#                                  Location  Total_Area  Price_per_SQFT  Baths  \
# 0            Kanathur Reddikuppam Chennai        2583            7700      4
# 1     Ramanathan Nagar PozhichalurChennai        7000            3210      6
# ...

# %%
plt.figure(figsize=(18, 12))

# Calculate correlation only for numeric columns
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")

plt.show()

# Pairplot for selected features (can include non-numeric columns)
selected_features = ["Property_Title", "Price_InLakhs" ,"Location", "Total_Area", "Price_per_SQFT", "Baths", "Balcony", "Typeof_flat"]
sns.pairplot(df[selected_features])
plt.show()

# %%
sns.FacetGrid(df, hue='Typeof_flat', height=6).map(sns.distplot, 'Balcony').add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# ...
